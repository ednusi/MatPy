# %%
# -Example
import numpy as np

import matplotlib.pyplot as plt

#By Lukas
from DataModelDict import DataModelDict as dmd

text_file = open('kolskybar.xml', "r")
qdata = dmd(text_file)
print qdata.xml(indent=2)

table = qdata.find('stressStrain')
distable = []
for row in table['rows'].iterlist('row'):
        disrow = []
        for column in row.iterlist('column'):
                disrow.append(column['#text'])
        distable.append(disrow)

del distable[0]
distable = np.array(distable)

print distable
# Out:
# [[  4.86122563e-06   9.89667340e+00  -5.96976005e+02]
#  [  2.61318576e-04  -1.33870592e+01   5.12914701e+02]
#  [  4.62210314e-04  -2.24729061e-01   4.01783476e+02]
#  [  6.05559733e-04   2.47553752e+00   2.86698838e+02]
#  [  7.17312026e-04  -5.29005181e+00   2.23504587e+02]
#  [  7.87446046e-04   1.29441974e+01   1.40268039e+02]
#  [  8.28805605e-04  -2.58873103e+00   8.27191187e+01]
#  [  8.46271018e-04   5.51507932e+00   3.49308260e+01]
#  [  8.40267039e-04  -4.27772643e+00  -1.20079591e+01]
#  [  8.22045951e-04  -4.61462834e+00  -3.64421751e+01]
#  [  7.79360128e-04   1.12507929e+00  -8.53716455e+01]
#  [  7.39405754e-04  -8.32868890e+00  -7.99087479e+01]
#  [  6.89379360e-04   1.66562762e+01  -1.00052789e+02]
#  [  6.34005778e-04  -9.67830153e+00  -1.10747165e+02]
#  [  5.85088514e-04   6.18945646e+00  -9.78345282e+01]
#  [  5.32561188e-04   4.83857619e+00  -1.05054651e+02]
#  [  4.87745349e-04  -1.33900907e+01  -8.96316784e+01]
#  [  4.42023119e-04   8.55157644e+00  -9.14444595e+01]
#  [  4.07560903e-04  -5.96310239e+00  -6.89244316e+01]
#  [  3.75958688e-04   5.17565655e+00  -6.32044299e+01]
#  [  3.59620691e-04  -9.00371042e-01  -3.26759944e+01]
#  [  3.63766357e-04   1.12461181e+00   8.29133106e+00]
#  [  3.72760475e-04  -2.24708960e-01   1.79882371e+01]
#  [  4.06432879e-04  -1.03510900e+01   6.73448073e+01]
#  [  4.53906087e-04   9.90111845e+00   9.49464162e+01]
#  [  5.09882330e-04  -7.31423711e+00   1.11952487e+02]
#  [  5.86403282e-04   1.12486222e+00   1.53041903e+02]
#  [  6.72815854e-04  -5.96468434e+00   1.72825144e+02]
#  [  7.90439645e-04  -1.57570632e+00   2.35247581e+02]
#  [  9.16272517e-04   1.12523334e+00   2.51665744e+02]
#  [  1.06155154e-03  -1.33977763e+01   2.90558053e+02]
#  [  1.22055575e-03   9.23347438e+00   3.18008417e+02]
#  [  1.39825598e-03  -6.64437060e+00   3.55400460e+02]
#  [  1.58716276e-03  -5.29465537e+00   3.77813557e+02]
#  [  1.78953461e-03   5.52028395e+00   4.04743705e+02]
#  [  2.01168221e-03  -3.26857719e+00   4.44295202e+02]
#  [  2.24300962e-03   7.89005282e+00   4.62654811e+02]
#  [  2.48779874e-03  -4.96087383e+00   4.89578237e+02]
#  [  2.74548586e-03   1.49993827e+01   5.15374250e+02]
#  [  3.00912413e-03  -3.27183903e+00   5.27276530e+02]
#  [  3.28408837e-03   9.59136957e+00   5.49928493e+02]
#  [  3.37088649e-01   8.42093717e+02   1.20929103e+02]
#  [  3.37121042e-01   8.39180847e+02   6.47855617e+01]
#  [  3.37112883e-01   8.37021683e+02  -1.63189728e+01]
#  [  3.37085118e-01   8.37044923e+02  -5.55299416e+01]
#  [  3.37013685e-01   8.41199677e+02  -1.42865477e+02]
#  [  3.36929782e-01   8.36448022e+02  -1.67806240e+02]
#  [  3.36822278e-01   8.13892594e+02  -2.15008382e+02]
#  [  3.36672472e-01   8.11847564e+02  -2.99612240e+02]
#  [  3.36487506e-01   8.10067994e+02  -3.69930617e+02]
#  [  3.36274974e-01   7.95058187e+02  -4.25063661e+02]
#  [  3.36026871e-01   8.01040175e+02  -4.96205883e+02]
#  [  3.35753908e-01   7.80996048e+02  -5.45926406e+02]
#  [  3.35442760e-01   7.84381814e+02  -6.22295871e+02]
#  [  3.35113480e-01   7.68950192e+02  -6.58560101e+02]
#  [  3.34745626e-01   7.63924261e+02  -7.35708980e+02]
#  [  3.34357031e-01   7.53837483e+02  -7.77190296e+02]
#  [  3.33940600e-01   7.36508442e+02  -8.32860951e+02]
#  [  3.33515455e-01   7.43834178e+02  -8.50290724e+02]
#  [  3.33075841e-01   7.14899352e+02  -8.79226575e+02]
#  [  3.32617802e-01   7.01680726e+02  -9.16079327e+02]]

# %%
p_alpha = 1
volume=50
fig, ax = plt.subplots(figsize=(12, 9))

ax.plot(distable[:,0],distable[:,1],lw=3) # plots first col vs second because stress vs strain
ax.tick_params(axis='x', labelsize=25, pad = 10)
ax.tick_params(axis='y', labelsize=25, pad = 10)


ax.grid(True)
fig.tight_layout()


plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import graph_suite as plot
import test_suite
reload(test_suite)

from DataModelDict import DataModelDict as dmd

table = dmd(open('kolskybar.xml', "r")).find('stressStrain')

distable = []

for row in table['rows'].iteraslist('row'):
    
        disrow = []
        
        for column in row.iteraslist('column'):
                disrow.append(column['#text'])
        
        distable.append(disrow)

del distable[0] # gets rid of header
distable = np.array(distable)

plot.plot2D(distable,'strain','stress','Stress vs. Strain for Carbon Model')

# %%
data = np.loadtxt('ref/HSRS/22')

test_suite.plot2D(data,'stress','strain','HSRS - 22')

# %%
data = np.loadtxt('ref/HSRS/222')

test_suite.plot2D(data,'stress','strain','HSRS - 222')

# %%
data = np.loadtxt('ref/HSRS/326')

test_suite.plot2D(data,'stress','strain','HSRS - 326')

# %% [markdown]
# ## By running optimization methods, we have determined the optimal parameters to be (-93.1687,0.878) for /ref/HSRS/22
#
# We must repeat this process for the other data sets and graph a comparison of the results. We can use ML to tailor this process as well, currently it is just minimizing

# %% [markdown]
# ## Now we do this for ref/HSRS/222

# %%
import test_suite as suite
import irreversible_stressstrain as model
reload(test_suite)
reload(model)

model.mcfunc((-100.,1.),'ref/HSRS/22')
# Out:
# 397.97064987549322

# %%
from irreversible_stressstrain import mcfunc
import test_suite as suite
suite.minimize_suite(mcfunc, ['L-BFGS-B'], [-100.,1] )
# Out:
# L-BFGS-B took 6.8727350235 seconds. The result, 397.946431254 was found at (-97.2268603274, 2.11310815695)
# L-BFGS-B used 88.14453125 megabytes and took 4.0 iterations

# %% [markdown]
# ## Now making this a class initializable with file to use

# %%
import test_suite
from irreversible_stressstrain import StressStrain
reload(test_suite)

model = StressStrain('ref/HSRS/22')
test_suite.minimize_suite(model.mcfunc,['L-BFGS-B'], [-100.,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fa48406896ed> in <module>()
#       4
#       5 model = StressStrain('ref/HSRS/22')
# ----> 6 test_suite.minimize_suite(model.mcfunc,['L-BFGS-B'], [-100.,1])
#
# /users/ean1/Documents/notebook_results/test_suite.pyc in minimize_suite(function, methods, guess)
#     163
#     164                 #tracks amount of memory used
# --> 165                 most_mem = np.append(most_mem, max(memory_usage((iter_minimize, (method, num_iters, start, stop, guess),))))
#     166                 num_iters, start, stop = iter_minimize(method, num_iters, start, stop, guess)
#     167
#
# /site/x86/anaconda-1.8/anaconda/lib/python2.7/site-packages/memory_profiler.pyc in memory_usage(proc, interval, timeout, timestamps, include_children, max_usage, retval, stream)
#     237             p.start()
#     238             parent_conn.recv()  # wait until we start getting memory
# --> 239             returned = f(*args, **kw)
#     240             parent_conn.send(0)  # finish timing
#     241             ret = parent_conn.recv()
#
# /users/ean1/Documents/notebook_results/test_suite.pyc in iter_minimize(method, num_iters, start, stop, guess)
#     148
#     149                         # Possibly was finding the iterations in the wrong order
# --> 150                         cur_result = minimize(function, x0 = guess, method = method, tol=1e-6)
#     151                         result.append(cur_result)
#     152
#
# /site/x86/anaconda-1.8/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     442     elif meth == 'l-bfgs-b':
#     443         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 444                                 callback=callback, **options)
#     445     elif meth == 'tnc':
#     446         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /site/x86/anaconda-1.8/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, **unknown_options)
#     318                 # minimization routine wants f and g at the current x
#     319                 # Overwrite f and g:
# --> 320                 f, g = func_and_grad(x)
#     321         elif task_str.startswith(b'NEW_X'):
#     322             # new iteration
#
# /site/x86/anaconda-1.8/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     264     if jac is None:
#     265         def func_and_grad(x):
# --> 266             f = fun(x, *args)
#     267             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     268             return f, g
#
# /site/x86/anaconda-1.8/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     283     def function_wrapper(*wrapper_args):
#     284         ncalls[0] += 1
# --> 285         return function(*(wrapper_args + args))
#     286
#     287     return ncalls, function_wrapper
#
# /users/ean1/Documents/notebook_results/irreversible_stressstrain.py in mcfunc(self, model_parameters)
#      92                 #print errors
#      93                 error_rms = _error_evaluation_rms(errors)
# ---> 94                 cal_val = np.asarray(cal_val)
#      95
#      96                 #print cal_val
#
# NameError: global name '_error_evaluation_rms' is not defined

# %%
# %matplotlib inline
import numpy as np
import graph_suite as plot
import test_suite

plot.plot2D(test_suite.xml_parse('kolskybar.xml'))
