# %%
import graph_suite as plot
import parser
reload(parser)
import material_analytics
reload(material_analytics)
import numpy as np

# %%
model = parser.stress_strain('ref/850-30.dat') 

data = model.get_experimental_data()[:,:2] # disregarding the strain rate

plot.plot2D(data, title = 'Stress vs Strain', xtitle = "Strain ($\epsilon$)", ytitle= "Stress ($\sigma$)")
#plot.texOn()
#plot.plot2D(data, title = 'Stress vs Strain', xtitle = "Strain ($\epsilon$)", ytitle= "Stress ($\sigma$)",
#           marker = 'o')

# %%
yieldpoint = material_analytics.yield_stress(data)
pts = []

for a in np.linspace(0,max(data[:,0]),1001):
    predicted = material_analytics.stress_model(data,a)[0]
    pts.append(predicted)
    
numpypoints = np.array(pts)

# %%
plot.plotmult2D(data,numpypoints, title = 'Stress vs Strain', xtitle = "Strain ($\epsilon$)", ytitle= "Stress ($\sigma$)")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-9a51edf20a3d> in <module>()
# ----> 1 plot.plotmult2D(data,numpypoints, title = 'Stress vs Strain', xtitle = "Strain ($\epsilon$)", ytitle= "Stress ($\sigma$)")
#
# /users/ean1/Documents/MatPy/devel/graph_suite.pyc in plotmult2D(data1, data2, xtitle, ytitle, title, marker1, marker2, fontsize)
#     168     # plot stress vs strain
#     169     ax.plot(data1[:,0],data1[:,1],marker1)
# --> 170     ax.plot(data2[:,0],data2[:,1],marker2)
#     171
#     172     ax.set_xlabel(xtitle)
#
# IndexError: too many indices for array

# %%
model = parser.stress_strain('ref/HSRS/22') 
data = model.get_experimental_data()

yieldpoint = material_analytics.yield_stress(data)
pts = []

for a in np.linspace(0,max(data[:,0]),1001):
    predicted = material_analytics.stress_model(data,a)[0]
    pts.append(predicted)
    
numpypoints = np.array(pts)
print numpypoints
# Out:
# [  0.           0.01668366   0.03336732 ...,  16.65029504  16.6669787
#   16.68366237]

# %%
plot.plotmult2D(data,numpypoints, title = 'Stress vs Strain', xtitle = "Strain ($\epsilon$)", ytitle= "Stress ($\sigma$)")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-9a51edf20a3d> in <module>()
# ----> 1 plot.plotmult2D(data,numpypoints, title = 'Stress vs Strain', xtitle = "Strain ($\epsilon$)", ytitle= "Stress ($\sigma$)")
#
# /users/ean1/Documents/MatPy/devel/graph_suite.pyc in plotmult2D(data1, data2, xtitle, ytitle, title, marker1, marker2, fontsize)
#     168     # plot stress vs strain
#     169     ax.plot(data1[:,0],data1[:,1],marker1)
# --> 170     ax.plot(data2[:,0],data2[:,1],marker2)
#     171
#     172     ax.set_xlabel(xtitle)
#
# IndexError: too many indices for array

# %%
model = parser.stress_strain('ref/850-30.dat') 

data = model.get_experimental_data()[:,:2] # disregarding the strain rate
yieldpoint = material_analytics.yield_stress(data)
pts = []

for a in np.linspace(0,max(data[:,0]),1001):
    predicted = material_analytics.stress_model(data,a)[0]
    pts.append(predicted)
    
numpypoints = np.array(pts)

print pts
# Out:
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# 455.230125523
# ...

# %%
import graph_suite as plot
import parser
reload(parser)
import material_analytics
reload(material_analytics)
import numpy as np

# %%
model = parser.stress_strain('ref/HSRS/222') 

data = model.get_experimental_data() # disregarding the strain rate

# the function that predicts values
predicted_model = material_analytics.stress_model(data)
predictions = np.empty(2)

for a in np.linspace(0,max(data[:,0]),1001):
    predictions = np.vstack((predictions, predicted_model(a)))

predictions = predictions[1:] # we are forced to add a first term, and then get rid of it

print material_analytics.young_modulus(data)
#plot.plotmult2D(data,predictions, title = 'Stress vs Strain',
#                marker1 = 'ro', marker2 = 'b-', xtitle = "Strain ($\epsilon$)", ytitle= "Stress ($\sigma$)")
# Out:
# 749.685539751

# %%
model = parser.stress_strain('ref/850-120.dat')
data = model.get_experimental_data()

# the function that predicts values
predicted_model = material_analytics.stress_model(data)
predictions = np.empty(2)

for a in np.linspace(0,max(data[:,0]),1001):
    predictions = np.vstack((predictions, predicted_model(a)))

predictions = predictions[1:] # we are forced to add a first term, and then get rid of it

plot.plotmult2D(data,predictions)

# %%
model = parser.stress_strain('kolskybar.xml',type='xml')
model = model.get_experimental_data()

startx = None
endx = None
cutoff = 0.0

"""Default interval values"""
if startx is None:
    startx=min(model[:,0])+0.1
if endx is None:
    endx=max(model[:,0])

"""We get rid of the noise in the data, and select only positive values (so that logarithms can be taken)"""
yieldpoint = material_analytics.yield_stress(model,cutoff = cutoff)

plot.plotmult2D(model,yieldpoint)
"""Fitting a log function to our data, bestfit is that function"""

model = material_analytics.log_prep(model,cutoff = cutoff)
bestfit = material_analytics.log_approx(model)
#plot.plotmult2D(material_analytics.samplepoints(bestfit,[0,max(model[:,0])],1000),model)
